# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
from datetime import datetime
import os
from pandas_profiling import ProfileReport
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
robinhood_path_aapl = "../data/external/popularity_export/AAPL.csv"

df_aapl = pd.read_csv(robinhood_path_aapl)
df_aapl['timestamp'] = df_aapl['timestamp'].map(lambda dt_string: datetime.strptime(dt_string, '%Y-%m-%d %H:%M:%S'))

# %%
print(df_aapl.head())
# Out:
#             timestamp  users_holding
# 0 2018-05-02 04:53:46         150785
# 1 2018-05-02 06:38:58         150785
# 2 2018-05-03 00:35:25         145510
# 3 2018-05-03 06:33:53         145510
# 4 2018-05-03 06:48:56         145510

# %%
plt.plot(df_aapl['timestamp'], df_aapl['users_holding'])
plt.title('Apple (AAPL) Popularity over Time')
plt.ylabel('Unique Robinhood Users Holding Shares')
# beautify the x-labels
plt.gcf().autofmt_xdate()

plt.show()
