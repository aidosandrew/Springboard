# %% [markdown]
# Predictive Analysis of Robinhood Popularity Data - Data Wrangling
#
# Purpose: In this module, we will analyze the Robinhood Popularity Data provided by RobinTrack, which tracks customer ownership of U.S. stocks on the Robinhood trading platform.
#
# Our goal is to determine if there are any features in the Robinhood data that provides meaningful insights into both historical (ex post) and prospective (ex ante) price returns (ex dividends).
#
# We will focus on a representative basket of 10 actively traded stocks over a two-period from July 1, 2018 to June 30, 2020.
#
# Data Sources: RobinTrack, https://robintrack.net/data-download, Yahoo API

# %%
# Importing modules for data wrangling and collection
# yfinance is a library for downloading hstorical market data from Yahoo finance

import numpy as np
import pandas as pd
from datetime import datetime
import yfinance as yf
import os

# %%
# Representative basket of 10 actively traded stocks on Robinhood
# Source: Robinhood, https://robinhood.com/collections/100-most-popular

stock_ticker = ['AAPL', 'AMZN', 'FB', 'GOOGL', 'JPM', 'MSFT', 'NFLX', 'NVDA', 'SQ', 'TSLA']
stock_name = ['Apple', 'Amazon', 'Facebook', 'Google', 'JPMorgan', 'Microsoft', 'Netflix', 'NVIDIA', 'Square', 'Tesla']
N = len(stock_ticker)

stock_list = dict(zip(stock_ticker,stock_name))
stock_list
# Out:
# {'AAPL': 'Apple',
#  'AMZN': 'Amazon',
#  'FB': 'Facebook',
#  'GOOGL': 'Google',
#  'JPM': 'JPMorgan',
#  'MSFT': 'Microsoft',
#  'NFLX': 'Netflix',
#  'NVDA': 'NVIDIA',
#  'SQ': 'Square',
#  'TSLA': 'Tesla'}

# %%
# The Robinhood Popularity data is stored in separate CSV files for each stock
# We're going to read in each CSV file as a dataframe and store it as a single list

df_list = list()

for ticker in stock_ticker:
    filepath = "../data/popularity_export/" + ticker + ".csv"
    df = pd.read_csv(filepath,parse_dates=[0])
    df.name = ticker
    df_list.append(df)

# %%
# Let's do a quick preview of the dataframes we've imported

for df in df_list:
    print(df.name)
    print(df.info())
# Out:
# AAPL
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19792 entries, 0 to 19791
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   timestamp      19792 non-null  datetime64[ns]
#  1   users_holding  19792 non-null  int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 309.4 KB
# None
# AMZN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19756 entries, 0 to 19755
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   timestamp      19756 non-null  datetime64[ns]
#  1   users_holding  19756 non-null  int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 308.8 KB
# None
# FB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19785 entries, 0 to 19784
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   timestamp      19785 non-null  datetime64[ns]
#  1   users_holding  19785 non-null  int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 309.3 KB
# None
# GOOGL
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19818 entries, 0 to 19817
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   timestamp      19818 non-null  datetime64[ns]
#  1   users_holding  19818 non-null  int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 309.8 KB
# None
# JPM
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19801 entries, 0 to 19800
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   timestamp      19801 non-null  datetime64[ns]
#  1   users_holding  19801 non-null  int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 309.5 KB
# None
# MSFT
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19785 entries, 0 to 19784
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   timestamp      19785 non-null  datetime64[ns]
#  1   users_holding  19785 non-null  int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 309.3 KB
# None
# NFLX
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19765 entries, 0 to 19764
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   timestamp      19765 non-null  datetime64[ns]
#  1   users_holding  19765 non-null  int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 309.0 KB
# None
# NVDA
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19802 entries, 0 to 19801
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   timestamp      19802 non-null  datetime64[ns]
#  1   users_holding  19802 non-null  int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 309.5 KB
# None
# SQ
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19822 entries, 0 to 19821
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   timestamp      19822 non-null  datetime64[ns]
#  1   users_holding  19822 non-null  int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 309.8 KB
# None
# TSLA
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19800 entries, 0 to 19799
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   timestamp      19800 non-null  datetime64[ns]
#  1   users_holding  19800 non-null  int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 309.5 KB
# None

# %%
# We want to filter just dates during our 2-year period of analysis
# We also just want to keep the last observation for each date

start_date = datetime(2018,7,1)
end_date = datetime(2020,7,1)

for i in range(N):
    
    # Time period filtering
    filter = (df_list[i]['timestamp'] >= start_date) & (df_list[i]['timestamp'] < end_date)
    df_list[i] = df_list[i].loc[filter]
    
    # Keep last observation for each date
    df_list[i] = df_list[i].groupby([df_list[i]['timestamp'].dt.date]).max()
    
    # We can drop the redundant timestamp column
    df_list[i].drop(columns=['timestamp'], inplace=True)
    
    print(df_list[i])
# Out:
#             users_holding
# timestamp
# 2018-07-01         150718
# 2018-07-02         150897
# 2018-07-03         151073
# 2018-07-04         151076
# 2018-07-05         151258
# ...                   ...
# 2020-06-26         484175
# 2020-06-27         484175
# 2020-06-28         484144
# 2020-06-29         486061
# 2020-06-30         489538
#
# [714 rows x 1 columns]
#             users_holding
# timestamp
# 2018-07-01          78884
# 2018-07-02          78950
# 2018-07-03          78903
# 2018-07-04          78903
# 2018-07-05          79221
# ...                   ...
# 2020-06-26         283515
# 2020-06-27         283515
# 2020-06-28         283499
# 2020-06-29         286784
# 2020-06-30         291879
#
# [714 rows x 1 columns]
#             users_holding
# timestamp
# 2018-07-01         104202
# 2018-07-02         104294
# 2018-07-03         104629
# 2018-07-04         104631
# 2018-07-05         104632
# ...                   ...
# 2020-06-26         227796
# 2020-06-27         227796
# 2020-06-28         227780
# 2020-06-29         233654
# 2020-06-30         235164
#
# [714 rows x 1 columns]
#             users_holding
# timestamp
# 2018-07-01          25723
# 2018-07-02          25749
# 2018-07-03          25747
# 2018-07-04          25747
# 2018-07-05          25799
# ...                   ...
# 2020-06-26          84525
# 2020-06-27          84525
# 2020-06-28          84521
# 2020-06-29          85375
# 2020-06-30          86153
#
# [714 rows x 1 columns]
#             users_holding
# timestamp
# 2018-07-01          15133
# 2018-07-02          15183
# 2018-07-03          15243
# 2018-07-04          15243
# 2018-07-05          15250
# ...                   ...
# 2020-06-26          84701
# 2020-06-27          84712
# 2020-06-28          84712
# 2020-06-29          85458
# 2020-06-30          85691
#
# [714 rows x 1 columns]
#             users_holding
# timestamp
# 2018-07-01         126912
# 2018-07-02         127219
# 2018-07-03         127318
# 2018-07-04         127318
# 2018-07-05         127406
# ...                   ...
# 2020-06-26         492290
# 2020-06-27         491739
# 2020-06-28         491705
# 2020-06-29         491898
# 2020-06-30         492023
#
# [714 rows x 1 columns]
#             users_holding
# timestamp
# 2018-07-01          95200
# 2018-07-02          95282
# 2018-07-03          95235
# 2018-07-04          95235
# 2018-07-05          95428
# ...                   ...
# 2020-06-26         146721
# 2020-06-27         146721
# 2020-06-28         146717
# 2020-06-29         147107
# 2020-06-30         148922
#
# [714 rows x 1 columns]
#             users_holding
# timestamp
# 2018-07-01          81092
# 2018-07-02          81235
# 2018-07-03          81848
# 2018-07-04          81848
# 2018-07-05          81992
# ...                   ...
# 2020-06-26         120392
# 2020-06-27         120392
# 2020-06-28         120385
# 2020-06-29         121398
# 2020-06-30         121503
#
# [714 rows x 1 columns]
#             users_holding
# timestamp
# 2018-07-01          59098
# 2018-07-02          59202
# 2018-07-03          59320
# 2018-07-04          59301
# 2018-07-05          59476
# ...                   ...
# 2020-06-26          89856
# 2020-06-27          89809
# 2020-06-28          89795
# 2020-06-29          89934
# 2020-06-30          89820
#
# [714 rows x 1 columns]
#             users_holding
# timestamp
# 2018-07-01          77403
# 2018-07-02          78811
# 2018-07-03          80178
# 2018-07-04          80180
# 2018-07-05          81785
# ...                   ...
# 2020-06-26         319386
# 2020-06-27         319386
# 2020-06-28         319371
# 2020-06-29         319998
# 2020-06-30         317022
#
# [714 rows x 1 columns]

# %%
# Let's pull in the prices and volume for each stock from the Yahoo API
# We want to right join on the stock price because it only includes trading days (exlcudes weekends and holidays)


for i in range(N):
    
    # Pulling pricing data
    price_data = yf.download(stock_ticker[i], start=start_date, end=end_date)
    
    # Closing price is the relevant price to keep, along with volume
    closing_data = price_data[['Close', 'Volume']]
    
    # Right join this data with our Robinhood participation data
    df_list[i] = df_list[i].merge(closing_data, how='right', left_index=True, right_index=True)
    
    # Let's also change the column names to be concise
    df_list[i].columns = ['Shares', 'Price', 'Volume']
    
    print(df_list[i])
# Out:
# [*********************100%***********************]  1 of 1 completed
#               Shares      Price     Volume
# Date
# 2018-07-02  150897.0  46.794998   70925200
# 2018-07-03  151073.0  45.980000   55819200
# 2018-07-05  151258.0  46.349998   66416800
# 2018-07-06  151150.0  46.992500   69940800
# 2018-07-09  150664.0  47.645000   79026400
# ...              ...        ...        ...
# 2020-06-24  481357.0  90.014999  192623200
# 2020-06-25  483107.0  91.209999  137522400
# 2020-06-26  484175.0  88.407501  205256800
# 2020-06-29  486061.0  90.445000  130646000
# 2020-06-30  489538.0  91.199997  140223200
#
# [503 rows x 3 columns]
# [*********************100%***********************]  1 of 1 completed
#               Shares        Price   Volume
# Date
# 2018-07-02   78950.0  1713.780029  3185700
# 2018-07-03   78903.0  1693.959961  2177300
# 2018-07-05   79221.0  1699.729980  2983100
# 2018-07-06   79175.0  1710.630005  2650300
# 2018-07-09   78968.0  1739.020020  3012000
# ...              ...          ...      ...
# 2020-06-24  277979.0  2734.399902  4526600
# 2020-06-25  280237.0  2754.580078  2968700
# 2020-06-26  283515.0  2692.870117  6500800
# 2020-06-29  286784.0  2680.379883  4223400
# 2020-06-30  291879.0  2758.820068  3769700
#
# [503 rows x 3 columns]
# [*********************100%***********************]  1 of 1 completed
#               Shares       Price    Volume
# Date
# 2018-07-02  104294.0  197.360001  13961600
# 2018-07-03  104629.0  192.729996  13489500
# 2018-07-05  104632.0  198.449997  19684200
# 2018-07-06  104302.0  203.229996  19740100
# 2018-07-09  104231.0  204.740005  18149400
# ...              ...         ...       ...
# 2020-06-24  219681.0  234.020004  20834900
# 2020-06-25  219856.0  235.679993  18704300
# 2020-06-26  227796.0  216.080002  76343900
# 2020-06-29  233654.0  220.639999  58514300
# 2020-06-30  235164.0  227.070007  33927100
#
# [503 rows x 3 columns]
# [*********************100%***********************]  1 of 1 completed
#              Shares        Price   Volume
# Date
# 2018-07-02  25749.0  1142.109985  1160800
# 2018-07-03  25747.0  1116.280029   822400
# 2018-07-05  25799.0  1141.290039  1429700
# 2018-07-06  25660.0  1155.079956  1091000
# 2018-07-09  25583.0  1167.280029  1079200
# ...             ...          ...      ...
# 2020-06-24  82097.0  1432.699951  1579600
# 2020-06-25  82457.0  1441.099976  1197900
# 2020-06-26  84525.0  1362.540039  4882000
# 2020-06-29  85375.0  1397.170044  2253700
# 2020-06-30  86153.0  1418.050049  2014300
#
# [503 rows x 3 columns]
# [*********************100%***********************]  1 of 1 completed
# 2020-06-25  318912.0  197.195999  46272500
# 2020-06-26  319386.0  191.947998  44274500
# 2020-06-29  319998.0  201.869995  45132000
# 2020-06-30  317022.0  215.962006  84592500
#
# [503 rows x 3 columns]

# %%
# Let's check for missing values

for df in df_list:
    print(df[df['Shares'].isnull()])
# Out:
#             Shares      Price     Volume
# Date
# 2018-08-09     NaN  52.220001   93970400
# 2019-01-24     NaN  38.174999  101766000
# 2019-01-25     NaN  39.439999  134142000
# 2019-01-28     NaN  39.075001  104768400
# 2019-01-29     NaN  38.669998  166348800
# 2020-01-07     NaN  74.597504  108872000
# 2020-01-08     NaN  75.797501  132079200
# 2020-01-09     NaN  77.407501  170108400
# 2020-01-10     NaN  77.582497  140644800
# 2020-01-13     NaN  79.239998  121532000
# 2020-01-14     NaN  78.169998  161954400
# 2020-01-15     NaN  77.834999  121923600
#             Shares        Price   Volume
# Date
# 2018-08-09     NaN  1898.520020  4860400
# 2019-01-24     NaN  1654.930054  4089900
# 2019-01-25     NaN  1670.569946  4945900
# 2019-01-28     NaN  1637.890015  4837700
# 2019-01-29     NaN  1593.880005  4632800
# 2020-01-07     NaN  1906.859985  4044900
# 2020-01-08     NaN  1891.969971  3508000
# 2020-01-09     NaN  1901.050049  3167300
# 2020-01-10     NaN  1883.160034  2853700
# 2020-01-13     NaN  1891.300049  2780800
# 2020-01-14     NaN  1869.439941  3440900
# 2020-01-15     NaN  1862.020020  2896600
#             Shares       Price    Volume
# Date
# 2018-08-09     NaN  183.089996  19732100
# 2019-01-24     NaN  145.830002  20955500
# 2019-01-25     NaN  149.009995  22237200
# 2019-01-28     NaN  147.470001  15508500
# 2019-01-29     NaN  144.190002  17632100
# 2020-01-07     NaN  213.059998  14912400
# 2020-01-08     NaN  215.220001  13475000
# 2020-01-09     NaN  218.300003  12642800
# 2020-01-10     NaN  218.059998  12119400
# 2020-01-13     NaN  221.910004  14463400
# 2020-01-14     NaN  219.059998  13288900
# 2020-01-15     NaN  221.149994  10036500
#             Shares        Price   Volume
# Date
# 2018-08-09     NaN  1264.459961  1366300
# 2019-01-24     NaN  1084.000000  1455700
# 2019-01-25     NaN  1101.510010  1163000
# 2019-01-28     NaN  1079.859985  1466700
# 2019-01-29     NaN  1070.060059   985200
# 2020-01-07     NaN  1395.109985  1716500
# 2020-01-08     NaN  1405.040039  1765700
# 2020-01-09     NaN  1419.790039  1660000
# 2020-01-10     NaN  1428.959961  1312900
# 2020-01-13     NaN  1440.030029  1536500
# 2020-01-14     NaN  1430.589966  1303800
# 2020-01-15     NaN  1439.199951  1077500
#             Shares       Price    Volume
# Date
# 2018-08-09     NaN  116.879997   9694200
# 2019-01-24     NaN  102.739998  11296800
# 2019-01-25     NaN  103.389999  14369400
# 2019-01-28     NaN  103.879997  12283100
# 2019-01-29     NaN  104.169998   9743300
# 2020-01-07     NaN  135.880005  10531300
# 2020-01-08     NaN  136.940002   9695300
# 2020-01-09     NaN  137.440002   9469000
# For the few missing Robinhood shares values, a forward fill makes sense

for i in range(N):
    df_list[i].ffill(axis=0,inplace=True)
    print(df_list[i])
# Out:
#               Shares      Price     Volume
# Date
# 2018-07-02  150897.0  46.794998   70925200
# 2018-07-03  151073.0  45.980000   55819200
# 2018-07-05  151258.0  46.349998   66416800
# 2018-07-06  151150.0  46.992500   69940800
# 2018-07-09  150664.0  47.645000   79026400
# ...              ...        ...        ...
# 2020-06-24  481357.0  90.014999  192623200
# 2020-06-25  483107.0  91.209999  137522400
# 2020-06-26  484175.0  88.407501  205256800
# 2020-06-29  486061.0  90.445000  130646000
# 2020-06-30  489538.0  91.199997  140223200
#
# [503 rows x 3 columns]
#               Shares        Price   Volume
# Date
# 2018-07-02   78950.0  1713.780029  3185700
# 2018-07-03   78903.0  1693.959961  2177300
# 2018-07-05   79221.0  1699.729980  2983100
# 2018-07-06   79175.0  1710.630005  2650300
# 2018-07-09   78968.0  1739.020020  3012000
# ...              ...          ...      ...
# 2020-06-24  277979.0  2734.399902  4526600
# 2020-06-25  280237.0  2754.580078  2968700
# 2020-06-26  283515.0  2692.870117  6500800
# 2020-06-29  286784.0  2680.379883  4223400
# 2020-06-30  291879.0  2758.820068  3769700
#
# [503 rows x 3 columns]
#               Shares       Price    Volume
# Date
# 2018-07-02  104294.0  197.360001  13961600
# 2018-07-03  104629.0  192.729996  13489500
# 2018-07-05  104632.0  198.449997  19684200
# 2018-07-06  104302.0  203.229996  19740100
# 2018-07-09  104231.0  204.740005  18149400
# ...              ...         ...       ...
# 2020-06-24  219681.0  234.020004  20834900
# 2020-06-25  219856.0  235.679993  18704300
# 2020-06-26  227796.0  216.080002  76343900
# 2020-06-29  233654.0  220.639999  58514300
# 2020-06-30  235164.0  227.070007  33927100
#
# [503 rows x 3 columns]
#              Shares        Price   Volume
# Date
# 2018-07-02  25749.0  1142.109985  1160800
# 2018-07-03  25747.0  1116.280029   822400
# 2018-07-05  25799.0  1141.290039  1429700
# 2018-07-06  25660.0  1155.079956  1091000
# 2018-07-09  25583.0  1167.280029  1079200
# ...             ...          ...      ...
# 2020-06-24  82097.0  1432.699951  1579600
# 2020-06-25  82457.0  1441.099976  1197900
# 2020-06-26  84525.0  1362.540039  4882000
# 2020-06-29  85375.0  1397.170044  2253700
# 2020-06-30  86153.0  1418.050049  2014300
#
# [503 rows x 3 columns]
#              Shares       Price    Volume
# Date
# 2018-07-02  15183.0  105.080002  11130000
# 2018-07-03  15243.0  103.610001   8311700
# 2018-07-05  15250.0  103.720001  10723400
# 2018-07-06  15258.0  104.059998  12173700
# 2018-07-09  15259.0  107.279999  13900800
# ...             ...         ...       ...
# 2020-06-24  83274.0   94.660004  22919800
# 2020-06-25  83498.0   97.959999  25743600
# 2020-06-26  84701.0   92.589996  41896300
# 2020-06-29  85458.0   93.000000  18499700
# 2020-06-30  85691.0   94.059998  19137000
#
# [503 rows x 3 columns]
#               Shares       Price    Volume
# Date
# 2018-07-02  127219.0  100.010002  19564500
# 2018-07-03  127318.0   99.050003  14670300
# 2018-07-05  127406.0   99.760002  18977400
# 2018-07-06  127306.0  101.160004  19234600
# 2018-07-09  126696.0  101.849998  18212000
# ...              ...         ...       ...
# 2020-06-24  491623.0  197.839996  36740600
# 2020-06-25  492319.0  200.339996  27803900
# 2020-06-26  492290.0  196.330002  54675800
# 2020-06-29  491898.0  198.440002  26701600
# 2020-06-30  492023.0  203.509995  34310300
#
# [503 rows x 3 columns]
#               Shares       Price    Volume
# Date
# 2018-07-02   95282.0  398.179993   8142500
# 2018-07-03   95235.0  390.519989   5280300
# 2018-07-05   95428.0  398.390015   8448900
# 2018-07-06   95170.0  408.250000   8629600
# 2018-07-09   94923.0  418.970001  11127500
# ...              ...         ...       ...
# 2020-06-24  145457.0  457.850006   4826200
# 2020-06-25  146096.0  465.910004   4134500
# 2020-06-26  146721.0  443.399994   6804700
# 2020-06-29  147107.0  447.239990   4844000
# 2020-06-30  148922.0  455.040009   4198500
#
# [503 rows x 3 columns]
#               Shares       Price    Volume
# Date
# 2018-07-02   81235.0  242.240005   8939300
# 2018-07-03   81848.0  236.839996   5568300
# 2018-07-05   81992.0  242.729996   7655400
# 2018-07-06   82020.0  247.330002   7408800
# 2018-07-09   82409.0  249.250000   7597000
# ...              ...         ...       ...
# 2020-06-24  118673.0  369.420013  11234300
# 2020-06-25  119455.0  379.600006   9401800
# 2020-06-26  120392.0  366.200012  14802100
# 2020-06-29  121398.0  368.000000   8556200
# 2020-06-30  121503.0  379.910004   9197300
#
# [503 rows x 3 columns]
#              Shares       Price    Volume
# Date
# 2018-07-02  59202.0   63.139999   5427100
# 2018-07-03  59320.0   61.750000   4234700
# 2018-07-05  59476.0   64.150002   7671000
# 2018-07-06  59545.0   66.440002  10441600
# 2018-07-09  59711.0   66.480003   9067800
# ...             ...         ...       ...
# 2020-06-24  89733.0  100.879997  13250400
# 2020-06-25  89820.0  104.779999  13569800
# 2020-06-26  89856.0  104.300003  19759100
# 2020-06-29  89934.0  103.680000   9210800
# 2020-06-30  89820.0  104.940002   7605100
#
# [503 rows x 3 columns]
#               Shares       Price    Volume
# Date
# 2018-07-02   78811.0   67.014000  93799000
# 2018-07-03   80178.0   62.172001  61413000
# 2018-07-05   81785.0   61.832001  87382000
# 2018-07-06   82743.0   61.779999  44327500
# 2018-07-09   83417.0   63.702000  37984000
# ...              ...         ...       ...
# 2020-06-24  316516.0  192.169998  54798000
# 2020-06-25  318912.0  197.195999  46272500
# 2020-06-26  319386.0  191.947998  44274500
# 2020-06-29  319998.0  201.869995  45132000
# 2020-06-30  317022.0  215.962006  84592500
#
# [503 rows x 3 columns]

# %%
# Let's check for duplicates rows

for df in df_list:
    print(df[df.duplicated()])
# Out:
# Empty DataFrame
# Columns: [Shares, Price, Volume]
# Index: []
# Empty DataFrame
# Columns: [Shares, Price, Volume]
# Index: []
# Empty DataFrame
# Columns: [Shares, Price, Volume]
# Index: []
# Empty DataFrame
# Columns: [Shares, Price, Volume]
# Index: []
# Empty DataFrame
# Columns: [Shares, Price, Volume]
# Index: []
# Empty DataFrame
# Columns: [Shares, Price, Volume]
# Index: []
# Empty DataFrame
# Columns: [Shares, Price, Volume]
# Index: []
# Empty DataFrame
# Columns: [Shares, Price, Volume]
# Index: []
# Empty DataFrame
# Columns: [Shares, Price, Volume]
# Index: []
# Empty DataFrame
# Columns: [Shares, Price, Volume]
# Index: []

# %%
# Finally, let's export the final dataset to separate CSVs

for i in range(N):
    filepath = "../data/" + stock_ticker[i] + ".csv"
    df = df_list[i].to_csv(filepath)
